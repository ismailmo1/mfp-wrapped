# %% [markdown]
# Click [here](https://nbviewer.org/github/ismailmo1/fit-analytics/blob/main/gym_eda.ipynb) to view the notebook - Github doesn't render the Plotly charts since it performs a static render

# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

# %%
# renders plotly in nbviewer
pio.renderers.default = 'notebook_connected'

# %%
gym_df = pd.read_csv("fitnotes/FitNotes_Export_2022_02_09_18_51_35.csv")
print(gym_df.info())
gym_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41783 entries, 0 to 41782
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           41783 non-null  object
#  1   Exercise       41783 non-null  object
#  2   Category       41783 non-null  object
#  3   Weight (kgs)   41770 non-null  float64
#  4   Reps           41770 non-null  float64
#  5   Distance       13 non-null     float64
#  6   Distance Unit  13 non-null     object
#  7   Time           13 non-null     object
#  8   Comment        1001 non-null   object
# dtypes: float64(3), object(6)
# memory usage: 2.9+ MB
# None
#          Date         Exercise   Category  Weight (kgs)  Reps  Distance  \
# 0  2015-10-19         Deadlift       Back         105.0   5.0       NaN
# 1  2015-10-19  Cable Face Pull  Shoulders          25.0  14.0       NaN
# 2  2015-10-19  Cable Face Pull  Shoulders          25.0  14.0       NaN
# 3  2015-10-19  Cable Face Pull  Shoulders          25.0  14.0       NaN
# 4  2015-10-19     Lat Pulldown       Back          41.0   7.0       NaN
#
#   Distance Unit Time Comment
# 0           NaN  NaN     NaN
# 1           NaN  NaN     NaN
# 2           NaN  NaN     NaN
# 3           NaN  NaN     NaN
# 4           NaN  NaN     NaN

# %%
# I don't track any distance/cardio activities so I'm surprised to see 13 values - (I do train cardio I promise!)
cardio_mask = ~gym_df['Distance'].isna()
gym_df[cardio_mask]
# Out:
#              Date            Exercise Category  Weight (kgs)  Reps  Distance  \
# 7612   2016-09-14      Rowing Machine   Cardio           NaN   NaN       2.0
# 7694   2016-09-17      Rowing Machine   Cardio           NaN   NaN       2.0
# 8050   2016-10-14      Rowing Machine   Cardio           NaN   NaN       0.5
# 16226  2017-12-16  Elbow Plank (Time)      Abs           NaN   NaN       0.0
# 16227  2017-12-16  Elbow Plank (Time)      Abs           NaN   NaN       0.0
# 16228  2017-12-16  Elbow Plank (Time)      Abs           NaN   NaN       0.0
# 16229  2017-12-16  Elbow Plank (Time)      Abs           NaN   NaN       0.0
# 23831  2019-04-06         StairMaster   Cardio           NaN   NaN       0.0
# 23914  2019-04-11         StairMaster   Cardio           NaN   NaN       0.0
# 23936  2019-04-12         StairMaster   Cardio           NaN   NaN       0.0
# 23951  2019-04-13         StairMaster   Cardio           NaN   NaN       0.0
# 23968  2019-04-14         StairMaster   Cardio           NaN   NaN       0.0
# 24086  2019-04-22         StairMaster   Cardio           NaN   NaN       0.0
#
#       Distance Unit     Time Comment
# 7612             km  0:08:28     NaN
# 7694             km  0:08:05     NaN
# 8050             km  0:02:00     NaN
# 16226             m  0:01:00     NaN
# 16227             m  0:01:00     NaN
# 16228             m  0:01:00     NaN
# 16229             m  0:01:00     NaN
# 23831             m  0:10:00     NaN
# 23914             m  0:30:00     NaN
# 23936             m  0:10:00     NaN
# 23951             m  0:20:00     NaN
# 23968             m  0:20:00     NaN
# 24086             m  0:20:00     NaN

# %%
# drop cardio entries
gym_df.drop(gym_df[cardio_mask].index, inplace=True)

#drop cardio related columns
gym_df.dropna(axis=1, how='all', inplace=True)
gym_df['Date'] = pd.to_datetime(gym_df['Date'])
gym_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41770 entries, 0 to 41782
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          41770 non-null  datetime64[ns]
#  1   Exercise      41770 non-null  object
#  2   Category      41770 non-null  object
#  3   Weight (kgs)  41770 non-null  float64
#  4   Reps          41770 non-null  float64
#  5   Comment       1001 non-null   object
# dtypes: datetime64[ns](1), float64(2), object(3)
# memory usage: 2.2+ MB

# %% [markdown]
# The app used for tracking allows you to enter comments for a particular set - i usually put in notes that say how difficult the set was, sometimes on a scale of 1-10, but the data is quite unstructured

# %%
gym_df['Comment'].value_counts()
# Out:
# 8                                     22
# 10                                    21
# 8.5                                   18
# 9.5                                   18
# Straps                                18
#                                       ..
# Mid and upper still rounding a bit     1
# Bad form                               1
# Failed 7th                             1
# Seconds                                1
# Dodgy second lockout (grip)            1
# Name: Comment, Length: 678, dtype: int64

# %% [markdown]
# #### How many days of workout data do we have?

# %%
num_workouts = len(gym_df.groupby('Date'))
max_date = gym_df['Date'].max().date()
min_date = gym_df['Date'].min().date()
day_delta = ( max_date-min_date).days

print(f"The data spans from {min_date} until {max_date}"
        f" and I worked out (or atleast tracked a workout) on {round((num_workouts/day_delta) *100)}% of those days ({num_workouts} days)")
# Out:
# The data spans from 2015-10-19 until 2022-02-09 and I worked out (or atleast tracked a workout) on 76% of those days (1745 days)

# %% [markdown]
# #### Let's have a look at how often I workout and when

# %%
gym_df_days = gym_df.groupby('Date').count()
gym_df_days.drop(gym_df.columns[1:], inplace=True, axis=1)
gym_df_days.reset_index(inplace=True)
gym_df_days['Year'] = gym_df_days['Date'].apply(lambda x:x.year)
gym_df_days['Month'] = gym_df_days['Date'].apply(lambda x:x.month)
gym_df_days['Weekday'] = gym_df_days['Date'].apply(lambda x:x.weekday())

# %%
gym_df_days.head()
# Out:
#         Date  Year  Month  Weekday
# 0 2015-10-19  2015     10        0
# 1 2015-10-20  2015     10        1
# 2 2015-10-21  2015     10        2
# 3 2015-10-22  2015     10        3
# 4 2015-10-23  2015     10        4

# %% [markdown]
# #### interesting that 2015 and 2022 are higher % and we have fewer data points - maybe the start and end of the year are better and then it drops off?

# %%
gym_df_counts = gym_df_days.groupby('Year').agg({'Date':['max','min', 'count']})
gym_df_counts = gym_df_counts.droplevel(level=0, axis=1)
gym_df_counts['num_days'] = (gym_df_counts['max'] - gym_df_counts['min'])
gym_df_counts['num_days'] = gym_df_counts['num_days'].apply(lambda x:x.days)
gym_df_counts['days_worked_out_%'] = gym_df_counts['count']/gym_df_counts['num_days']
gym_df_counts['days_worked_out_%'] = gym_df_counts['days_worked_out_%'].apply(lambda x:round(x*100, 2))
gym_df_counts
# Out:
#             max        min  count  num_days  days_worked_out_%
# Year
# 2015 2015-12-17 2015-10-19     51        59              86.44
# 2016 2016-12-31 2016-01-03    293       363              80.72
# 2017 2017-12-31 2017-01-02    268       363              73.83
# 2018 2018-12-31 2018-01-02    263       363              72.45
# 2019 2019-12-31 2019-01-01    277       364              76.10
# 2020 2020-12-30 2020-01-02    284       363              78.24
# 2021 2021-12-30 2021-01-01    277       363              76.31
# 2022 2022-02-09 2022-01-01     32        39              82.05

# %%
gym_df_counts.reset_index(inplace=True)
fig = px.line(data_frame = gym_df_counts, x='Year', y='days_worked_out_%', hover_data = ['num_days'], title='Percentage of Days Worked Out')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="b457649e-3ef7-4c1a-85a6-383656ab2a4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b457649e-3ef7-4c1a-85a6-383656ab2a4b")) {                    Plotly.newPlot(                        "b457649e-3ef7-4c1a-85a6-383656ab2a4b",                        [{"customdata":[[59],[363],[363],[363],[364],[363],[363],[39]],"hovertemplate":"Year=%{x}<br>days_worked_out_%=%{y}<br>num_days=%{customdata[0]}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[86.44,80.72,73.83,72.45,76.1,78.24,76.31,82.05],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"col ...

# %% [markdown]
# so going to the gym often is cool but have I made any actual progress? Let's shift our focus to performance improvements

# %%
gym_df['Exercise'].value_counts().head(15)
# Out:
# Pull Up                         3656
# Flat Barbell Bench Press        1674
# Barbell Squat                   1438
# V-Bar Push Down                 1146
# Incline Dumbbell Bench Press    1126
# Cable Crunch                    1041
# Overhead Press                   941
# Deadlift                         859
# Sumo Deadlift                    816
# Hammer Cable Curl                809
# Seated Cable Row                 742
# High Cable Fly                   731
# Lateral Machine Raise            729
# Lateral Dumbbell Raise           694
# Rope Push Down                   642
# Name: Exercise, dtype: int64

# %%
gym_df['Category'].value_counts()
# Out:
# Back          9960
# Chest         7618
# Shoulders     6082
# Legs          6052
# Triceps       5122
# Biceps        4343
# Abs           1854
# Bodyweight     403
# Neck           206
# Forearms       130
# Name: Category, dtype: int64

# %% [markdown]
# top 2 most common exercises per category

# %%
most_common_ex = gym_df.groupby('Category').apply(lambda x:x['Exercise'].value_counts()[0:2])
most_common_ex
# Out:
# Category
# Abs         Cable Crunch                    1041
#             Hanging Knee Raise               326
# Back        Pull Up                         3656
#             Deadlift                         859
# Biceps      Hammer Cable Curl                809
#             EZ-Bar Curl                      558
# Bodyweight  Push Ups                         208
#             Chin Up                          106
# Chest       Flat Barbell Bench Press        1674
#             Incline Dumbbell Bench Press    1126
# Forearms    Forearm Curl                     130
# Legs        Barbell Squat                   1438
#             Sumo Deadlift                    816
# Neck        Lying Neck Curl                  121
#             Lying Neck Extension              85
# Shoulders   Overhead Press                   941
#             Lateral Machine Raise            729
# Triceps     V-Bar Push Down                 1146
#             Rope Push Down                   642
# Name: Exercise, dtype: int64

# %%
# only focus on major muscle groups
most_common_ex.drop(['Abs', 'Bodyweight', 'Forearms', 'Neck'], inplace=True)

# %%
compound_ex = ['Deadlift', 'Sumo Deadlift', 'Barbell Squat', 'Flat Barbell Bench Press']

# %%
def plot_progress(exercise):
    """Plot line plot of exercise weight separated by reps"""
    
    exercise_df = gym_df[gym_df['Exercise'] == f'{exercise}'][['Date', 'Weight (kgs)', 'Reps']]
    exercise_df.drop(exercise_df[exercise_df['Reps']==0].index, inplace=True)
    return px.line(exercise_df, x='Date', y='Weight (kgs)', color= 'Reps', 
    markers=True, 
    title=f'{exercise} Progress', 
    range_x = [gym_df['Date'].min() - pd.DateOffset(months=1), gym_df['Date'].max()+ pd.DateOffset(months=1)])

# %%
for exercise in compound_ex:
    plot_progress(exercise).show()
# Out:
# <div>                            <div id="6701c4da-e646-4979-a855-4d483b56b57b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6701c4da-e646-4979-a855-4d483b56b57b")) {                    Plotly.newPlot(                        "6701c4da-e646-4979-a855-4d483b56b57b",                        [{"hovertemplate":"Reps=5.0<br>Date=%{x}<br>Weight (kgs)=%{y}<extra></extra>","legendgroup":"5.0","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"5.0","orientation":"v","showlegend":true,"x":["2015-10-19T00:00:00","2015-11-23T00:00:00","2015-11-23T00:00:00","2015-12-14T00:00:00","2016-01-04T00:00:00","2016-01-04T00:00:00","2016-01-04T00:00:00","2016-01-04T00:00:00","2016-01-11T00:00:00","2016-01-11T00:00:00","2016-01-11T00:00:00","2016-01-18T00:00:00","2016-01-18T00:00:00","2016-01-18T00:00:00","2016-01-18T00:00:00","2016-01-18T00:00:00","2016-01-18T00:00:00","2016-01-25T00:00:00","2016-01-25T00:00:00","2016-01-25T00:00:00","2016-01-28T00:00:00","2016-01-28T00:00:00","2016-01-28T00:00:00","2016-02-01T00:00:00","2016-02-01T00:00:00","2016-02-01T00:00:00","2016-02-08T00:00:00","2016-02-08T00:00:00","2016-02-08T00:00:00","2016-02-08T00:00:00","2016-02-11T00:00:00","2016-02-11T00:00:00","2016-02-11T00:00:00","2016-02-11T00:00:00","2016-02-11T00:00:00","2016-02-15T00:00:00","2016-02-15T00:00:00","2016-02-15T00:00:00","2016-02-15T00:00:00","2016-02-22T00:00:00","2016-02-22T00:00:00","2016-02-22T00:00:00","2016-02-22T00:00:00","2016-02-22T00:00:00","2016-02-29T00:00:00","2016-02-29T00:00:00","2016-02-29T00:00:00","2016-03-07T00:00:00","2016-03-07T00:00:00","2016-03-07T00:00:00","2016-03-21T00:00:00","2016-03-21T00:00:00","2016-03-28T00:00:00","2016-03-28T00:00:00","2016-04-04T00:00:00","2016-04-04T00:00:00","2016-04-04T00:00:00","2016-04-11T00:00:00","2016-04-11T00:00:00","2016-04-11T00:00:00","2016-04-14T00:00:00","2016-04-14T00:00:00","2016-04-18T00:00:00","2016-04-25T00:00:00","2016-05-02T00:00:00","2016-05-02T00:00:00","2016-05-09T00:00:00","2016-05-09T00:00:00","2016-05-16T00:00:00","2016-05-16T00:00:00","2016-05-19T00:00:00","2016-05-23T00:00:00","2016-05-23T00:00:00","2016-05-28T00:00:00","2016-05-30T00:00:00","2016-05-30T00:00:00","2016-06-01T00:00:00","2016-06-01T00:00:00","2016-07-06T00:00:00","2016-07-09T00:00:00","2016-07-14T00:00:00","2016-07-14T00:00:00","2016-07-17T00:00:00","2016-07-24T00:00:00","2016-07-24T00:00:00","2016-07-28T00:00:00","2016-07-31T00:00:00","2016-07-31T00:00:00","2016-07-31T00:00:00","2016-07-31T00:00:00","2016-08-04T00:00:00","2016-08-04T00:00:00","2016-08-04T00:00:00","2016-08-14T00:00:00","2016-08-18T00:00:00","2016-08-18T00:00:00","2016-08-18T00:00:00","2016-08-28T00:00:00","2016-09-02T00:00:00","2016-09-02T00:00:00","2016-09-02T00:00:00","2016-09-13T00:00:00","2016-09-17T00:00:00","2016-09-17T00:00:00","2016-09-17T00:00:00","2016-09-21T00:00:00","2016-09-21T00:00:00","2016-09-21T00:00:00","2016-10-01T00:00:00","2016-10-13T00:00:00","2016-10-13T00:00:00","2017-01-10T00:00:00","2017-01-24T00:00:00","2017-02-21T00:00:00","2017-02-28T00:00:00","2017-03-07T00:00:00","2017-03-14T00:00:00","2017-03-21T00:00:00","2017-04-04T00:00:00","2017-04-11T00:00:00","2017-06-26T00:00:00","2017-06-26T00:00:00","2017-06-26T00:00:00","2017-06-26T00:00:00","2017-06-26T00:00:00","2017-07-12T00:00:00","2017-07-12T00:00:00","2017-07-12T00:00:00","2017-07-18T00:00:00","2017-07-18T00:00:00","2017-07-18T00:00:00","2017-07-18T00:00:00","2017-08-02T00:00:00","2017-08-02T00:00:00","2017-08-02T00:00:00","2017-08-02T00:00:00","2017-09-02T00:00:00","2017-09-02T00:00:00","2017-09-02T00:00:00","2017-09-09T00:00:00","2017-09-09T00:00:00","2017-09-09T00:00:00","2017-09-09T00:00:00","2017-09-09T00:00:00","2018-05-03T00:00:00","2018-06-16T00:00:00","2018-06-16T ...
# <div>                            <div id="655d5170-86dc-4d2f-9b6e-cff14db621a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("655d5170-86dc-4d2f-9b6e-cff14db621a6")) {                    Plotly.newPlot(                        "655d5170-86dc-4d2f-9b6e-cff14db621a6",                        [{"hovertemplate":"Reps=5.0<br>Date=%{x}<br>Weight (kgs)=%{y}<extra></extra>","legendgroup":"5.0","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"5.0","orientation":"v","showlegend":true,"x":["2017-01-26T00:00:00","2017-01-26T00:00:00","2017-01-26T00:00:00","2017-01-26T00:00:00","2017-01-26T00:00:00","2017-02-23T00:00:00","2017-02-23T00:00:00","2017-02-23T00:00:00","2017-03-02T00:00:00","2017-03-02T00:00:00","2017-03-02T00:00:00","2017-03-09T00:00:00","2017-03-09T00:00:00","2017-03-09T00:00:00","2017-03-16T00:00:00","2017-03-16T00:00:00","2017-03-16T00:00:00","2017-03-23T00:00:00","2017-03-30T00:00:00","2017-03-30T00:00:00","2017-03-30T00:00:00","2017-03-30T00:00:00","2017-04-06T00:00:00","2017-07-29T00:00:00","2017-08-14T00:00:00","2017-08-14T00:00:00","2017-08-14T00:00:00","2017-08-16T00:00:00","2017-08-16T00:00:00","2017-08-20T00:00:00","2017-09-05T00:00:00","2017-09-05T00:00:00","2017-09-05T00:00:00","2017-09-11T00:00:00","2017-09-18T00:00:00","2017-09-25T00:00:00","2017-10-10T00:00:00","2017-10-10T00:00:00","2017-10-16T00:00:00","2017-10-18T00:00:00","2017-12-18T00:00:00","2017-12-18T00:00:00","2017-12-18T00:00:00","2018-01-28T00:00:00","2018-02-15T00:00:00","2018-02-23T00:00:00","2018-03-28T00:00:00","2018-03-28T00:00:00","2018-03-28T00:00:00","2018-04-26T00:00:00","2018-04-26T00:00:00","2018-05-15T00:00:00","2018-05-30T00:00:00","2018-06-18T00:00:00","2018-06-18T00:00:00","2018-06-18T00:00:00","2018-07-03T00:00:00","2018-07-03T00:00:00","2018-07-03T00:00:00","2018-08-06T00:00:00","2018-09-20T00:00:00","2018-09-20T00:00:00","2018-11-23T00:00:00","2019-01-09T00:00:00","2019-02-22T00:00:00","2019-02-22T00:00:00","2019-02-22T00:00:00","2019-03-28T00:00:00","2019-03-28T00:00:00","2019-05-18T00:00:00","2019-05-18T00:00:00","2019-05-18T00:00:00","2019-06-11T00:00:00","2019-06-11T00:00:00","2019-06-18T00:00:00","2019-06-18T00:00:00","2020-02-23T00:00:00","2020-02-23T00:00:00","2020-09-29T00:00:00","2020-12-29T00:00:00","2020-12-29T00:00:00","2020-12-29T00:00:00","2021-04-15T00:00:00","2021-04-15T00:00:00","2021-04-15T00:00:00","2021-05-03T00:00:00","2021-06-19T00:00:00","2021-06-19T00:00:00","2021-06-19T00:00:00","2021-06-26T00:00:00","2021-07-27T00:00:00","2021-08-01T00:00:00","2021-08-01T00:00:00","2021-08-01T00:00:00","2021-08-01T00:00:00","2021-08-01T00:00:00","2021-08-19T00:00:00","2021-09-15T00:00:00","2021-09-15T00:00:00","2021-09-15T00:00:00","2021-10-25T00:00:00","2021-10-25T00:00:00","2021-10-25T00:00:00","2021-10-25T00:00:00","2021-10-25T00:00:00","2021-11-15T00:00:00","2021-12-13T00:00:00","2021-12-13T00:00:00","2021-12-13T00:00:00","2022-01-24T00:00:00","2022-01-24T00:00:00","2022-01-24T00:00:00","2022-01-24T00:00:00"],"xaxis":"x","y":[50.0,70.0,80.0,80.0,80.0,87.5,102.5,120.0,87.5,102.5,120.0,87.5,105.0,122.5,90.0,107.5,125.0,125.0,100.0,100.0,100.0,100.0,125.0,150.0,120.0,120.0,120.0,110.0,110.0,60.0,140.0,140.0,140.0,147.5,152.5,157.5,155.0,155.0,145.0,160.0,142.5,142.5,142.5,170.0,175.0,180.0,157.5,157.5,157.5,70.0,70.0,120.0,60.0,160.0,160.0,160.0,162.5,162.5,162.5,60.0,60.0,60.0,187.5,130.0,160.0,160.0,160.0,120.0,120.0,180.0,180.0,140.0,160.0,160.0,180.0,160.0,160.0,160.0,160.0,160.0,160.0,160.0,140.0,140.0,140.0,140.0,150.0,150.0,150.0,170.0,170.0,160.0,160.0,160.0,160.0,160.0,180.0,165.0,165.0,165.0,175.0,175.0,175.0,175.0,175.0,182.5,170.0,170.0,170.0,180.0,180.0,180.0,180.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Reps=3.0< ...
# <div>                            <div id="a8bc67a7-894f-452e-90b6-8d6621236ffc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8bc67a7-894f-452e-90b6-8d6621236ffc")) {                    Plotly.newPlot(                        "a8bc67a7-894f-452e-90b6-8d6621236ffc",                        [{"hovertemplate":"Reps=5.0<br>Date=%{x}<br>Weight (kgs)=%{y}<extra></extra>","legendgroup":"5.0","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"5.0","showlegend":true,"x":["2015-10-21T00:00:00","2015-10-21T00:00:00","2015-10-28T00:00:00","2015-10-28T00:00:00","2015-10-31T00:00:00","2015-10-31T00:00:00","2015-10-31T00:00:00","2015-11-11T00:00:00","2015-11-11T00:00:00","2015-11-14T00:00:00","2015-11-14T00:00:00","2015-11-25T00:00:00","2015-11-25T00:00:00","2015-11-25T00:00:00","2015-11-25T00:00:00","2015-11-28T00:00:00","2015-11-28T00:00:00","2015-11-28T00:00:00","2015-12-02T00:00:00","2015-12-02T00:00:00","2015-12-05T00:00:00","2015-12-05T00:00:00","2015-12-05T00:00:00","2015-12-09T00:00:00","2015-12-09T00:00:00","2015-12-09T00:00:00","2015-12-16T00:00:00","2015-12-16T00:00:00","2015-12-16T00:00:00","2016-01-06T00:00:00","2016-01-06T00:00:00","2016-01-06T00:00:00","2016-01-06T00:00:00","2016-01-06T00:00:00","2016-01-13T00:00:00","2016-01-13T00:00:00","2016-01-13T00:00:00","2016-01-13T00:00:00","2016-01-13T00:00:00","2016-01-20T00:00:00","2016-01-20T00:00:00","2016-01-20T00:00:00","2016-01-23T00:00:00","2016-01-23T00:00:00","2016-01-23T00:00:00","2016-01-23T00:00:00","2016-01-23T00:00:00","2016-01-27T00:00:00","2016-01-27T00:00:00","2016-01-27T00:00:00","2016-01-27T00:00:00","2016-01-27T00:00:00","2016-01-30T00:00:00","2016-01-30T00:00:00","2016-01-30T00:00:00","2016-01-30T00:00:00","2016-01-30T00:00:00","2016-02-03T00:00:00","2016-02-03T00:00:00","2016-02-03T00:00:00","2016-02-03T00:00:00","2016-02-03T00:00:00","2016-02-03T00:00:00","2016-02-03T00:00:00","2016-02-06T00:00:00","2016-02-06T00:00:00","2016-02-06T00:00:00","2016-02-06T00:00:00","2016-02-10T00:00:00","2016-02-10T00:00:00","2016-02-10T00:00:00","2016-02-10T00:00:00","2016-02-10T00:00:00","2016-02-13T00:00:00","2016-02-13T00:00:00","2016-02-13T00:00:00","2016-02-17T00:00:00","2016-02-17T00:00:00","2016-02-17T00:00:00","2016-02-17T00:00:00","2016-02-20T00:00:00","2016-02-20T00:00:00","2016-02-20T00:00:00","2016-02-24T00:00:00","2016-02-24T00:00:00","2016-02-24T00:00:00","2016-02-24T00:00:00","2016-02-24T00:00:00","2016-02-24T00:00:00","2016-02-27T00:00:00","2016-02-27T00:00:00","2016-02-27T00:00:00","2016-02-27T00:00:00","2016-02-27T00:00:00","2016-03-02T00:00:00","2016-03-02T00:00:00","2016-03-02T00:00:00","2016-03-05T00:00:00","2016-03-05T00:00:00","2016-03-05T00:00:00","2016-03-05T00:00:00","2016-03-05T00:00:00","2016-03-09T00:00:00","2016-03-09T00:00:00","2016-03-09T00:00:00","2016-03-12T00:00:00","2016-03-12T00:00:00","2016-03-12T00:00:00","2016-03-12T00:00:00","2016-03-12T00:00:00","2016-03-16T00:00:00","2016-03-16T00:00:00","2016-03-19T00:00:00","2016-03-19T00:00:00","2016-03-19T00:00:00","2016-03-19T00:00:00","2016-04-06T00:00:00","2016-04-06T00:00:00","2016-04-06T00:00:00","2016-04-06T00:00:00","2016-04-06T00:00:00","2016-04-06T00:00:00","2016-04-06T00:00:00","2016-04-09T00:00:00","2016-04-16T00:00:00","2016-04-16T00:00:00","2016-04-20T00:00:00","2016-04-20T00:00:00","2016-04-20T00:00:00","2016-04-20T00:00:00","2016-04-20T00:00:00","2016-04-23T00:00:00","2016-04-23T00:00:00","2016-04-23T00:00:00","2016-04-27T00:00:00","2016-04-27T00:00:00","2016-04-30T00:00:00","2016-04-30T00:00:00","2016-04-30T00:00:00","2016-05-04T00:00:00","2016-05-04T00:00:00","2016-05-04T00:00:00","2016-05-04T00:00:00","2016-05-04T00:00:00","2016-05-07T00:00:00","2016-05-07T00:00:00","2016-05-07T00:00:00","2016-05 ...
# <div>                            <div id="19d2c7b7-94a4-4c18-963b-4ad7e3971948" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19d2c7b7-94a4-4c18-963b-4ad7e3971948")) {                    Plotly.newPlot(                        "19d2c7b7-94a4-4c18-963b-4ad7e3971948",                        [{"hovertemplate":"Reps=4.0<br>Date=%{x}<br>Weight (kgs)=%{y}<extra></extra>","legendgroup":"4.0","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"4.0","showlegend":true,"x":["2015-10-20T00:00:00","2015-10-23T00:00:00","2015-10-27T00:00:00","2015-10-30T00:00:00","2015-10-30T00:00:00","2015-11-03T00:00:00","2015-11-03T00:00:00","2015-11-03T00:00:00","2015-11-03T00:00:00","2015-11-06T00:00:00","2015-11-10T00:00:00","2015-11-10T00:00:00","2015-11-10T00:00:00","2015-11-10T00:00:00","2015-11-17T00:00:00","2015-11-20T00:00:00","2015-11-20T00:00:00","2015-12-01T00:00:00","2015-12-08T00:00:00","2015-12-08T00:00:00","2015-12-15T00:00:00","2015-12-15T00:00:00","2016-01-03T00:00:00","2016-01-12T00:00:00","2016-01-19T00:00:00","2016-01-26T00:00:00","2016-02-02T00:00:00","2016-02-09T00:00:00","2016-02-09T00:00:00","2016-02-12T00:00:00","2016-02-14T00:00:00","2016-02-14T00:00:00","2016-02-14T00:00:00","2016-02-16T00:00:00","2016-02-23T00:00:00","2016-02-26T00:00:00","2016-03-04T00:00:00","2016-03-06T00:00:00","2016-03-06T00:00:00","2016-03-06T00:00:00","2016-03-08T00:00:00","2016-03-11T00:00:00","2016-03-18T00:00:00","2016-03-18T00:00:00","2016-04-08T00:00:00","2016-04-08T00:00:00","2016-04-08T00:00:00","2016-04-15T00:00:00","2016-04-15T00:00:00","2016-04-15T00:00:00","2016-04-22T00:00:00","2016-04-22T00:00:00","2016-04-29T00:00:00","2016-05-01T00:00:00","2016-05-01T00:00:00","2016-05-06T00:00:00","2016-05-06T00:00:00","2016-05-13T00:00:00","2016-05-20T00:00:00","2016-07-07T00:00:00","2016-07-11T00:00:00","2016-07-15T00:00:00","2016-07-15T00:00:00","2016-07-22T00:00:00","2016-07-29T00:00:00","2016-07-29T00:00:00","2016-08-12T00:00:00","2016-09-01T00:00:00","2016-09-20T00:00:00","2016-11-26T00:00:00","2016-11-26T00:00:00","2016-11-26T00:00:00","2016-12-03T00:00:00","2016-12-03T00:00:00","2016-12-03T00:00:00","2016-12-03T00:00:00","2016-12-03T00:00:00","2016-12-10T00:00:00","2016-12-10T00:00:00","2016-12-10T00:00:00","2016-12-10T00:00:00","2016-12-10T00:00:00","2016-12-10T00:00:00","2017-01-23T00:00:00","2017-01-23T00:00:00","2017-01-23T00:00:00","2017-01-23T00:00:00","2017-01-28T00:00:00","2017-01-28T00:00:00","2017-01-30T00:00:00","2017-01-30T00:00:00","2017-02-20T00:00:00","2017-02-20T00:00:00","2017-02-27T00:00:00","2017-02-27T00:00:00","2017-02-27T00:00:00","2017-03-06T00:00:00","2017-03-06T00:00:00","2017-03-20T00:00:00","2017-03-20T00:00:00","2017-04-03T00:00:00","2017-04-10T00:00:00","2017-04-10T00:00:00","2017-04-10T00:00:00","2017-04-10T00:00:00","2017-04-18T00:00:00","2017-04-25T00:00:00","2017-05-03T00:00:00","2017-05-03T00:00:00","2017-05-06T00:00:00","2017-05-06T00:00:00","2017-05-06T00:00:00","2017-05-12T00:00:00","2017-07-07T00:00:00","2017-07-07T00:00:00","2017-07-07T00:00:00","2017-07-07T00:00:00","2017-07-11T00:00:00","2017-07-17T00:00:00","2017-07-17T00:00:00","2017-07-17T00:00:00","2017-07-17T00:00:00","2017-07-17T00:00:00","2017-07-17T00:00:00","2017-07-17T00:00:00","2017-07-28T00:00:00","2017-07-28T00:00:00","2017-07-28T00:00:00","2017-07-28T00:00:00","2017-08-01T00:00:00","2017-09-08T00:00:00","2017-09-08T00:00:00","2017-09-15T00:00:00","2017-10-13T00:00:00","2017-10-20T00:00:00","2017-10-27T00:00:00","2017-11-04T00:00:00","2017-12-17T00:00:00","2018-01-26T00:00:00","2018-02-02T00:00:00","2018-02-13T00:00:00","2018-02-13T00:00:00","2018-02-13T00:00:00","2018-02-20T00:00:00","2018-02-20T00:00:00","2018-02-27T00:00:00","2018-03-03T00:00:00","2018-03 ...
